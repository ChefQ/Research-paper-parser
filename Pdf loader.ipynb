# %%
from selenium import webdriver 
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from google.oauth2 import service_account
from selenium.webdriver.common.by import By


import PyPDF2

from PyPDF2 import PdfReader, PdfWriter
import requests
import regex as re
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import Select
web_pages = dict()
import vlc
import pdfplumber
import regex as re
import pdb
import regex as re
# from PyPDF2 import PdfFileReader, PdfFileWriter
from pdf2image import convert_from_path
import pytesseract
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

SAMPLE_SPREADSHEET_ID = '1kge8VOTe7oUNFagXmP2f3HdgI0j4-y2wOQlcTjuuTy0'

SAMPLE_RANGE_NAME = 'A2:D7'
p = vlc.MediaPlayer("/Users/profq/Downloads/morning-in-a-big-city-8099.mp3")


def findLink(tag):
    if tag.name == "span" and tag.a != None and tag.get("class") != None:
        cond = "gateway.proquest.com"
        if tag["class"][0] == 'subjectField-postProcessingHook' and cond in tag.a["href"]:
            return True
    return False
def findCapcha(tag):
    if tag.name =="div" and div.get("id") == "start":
        if tag.div.get("class") == "alert alert-info container captcha_alert_box":
            return True
    return False

def getBs(link):
    """
    This function takes a proquest Url
    and returns the beautiful soup object
    """
    driver.get(link)
    sleep(3)
    html = driver.execute_script("return document.documentElement.outerHTML;")
    bs = BeautifulSoup(html, "html5lib")
    capcha1 = bs.find_all("div", attrs = {"class": "alert alert-info container captcha_alert_box"} )
    playing = False
    while(len(capcha1) != 0 ):
        print("start playing alarm")
        p.play()
        playing = True
        sleep(5)
        break
    if(playing == True):
        p.stop()
    return bs

def goToPage(num): 
    """
    This function takes the browser to the specific page num
    This fucntion is useful because sometimes mid way in downloading.
    A bot check stops the program.
    We need a way to go back to our intended page number to continue downloading
    """
    pass

def writeContent(pdf): # come here to change code
    response = requests.get(pdf) 
    with open('./dissertation.pdf', 'wb') as f:
        f.write(response.content)
        sleep(4)  
    ack1 = findAck()
    ack2 = findAck2()
    return ack1, ack2

def getAckFromLines(lines,ACK2=None):
    # numeral numbers
    regex1 = r"[^\w]+i$+|^i$|^1[^\w]+|[^\w]+1$+|^1$|"
    regex2 = r"^ii[^\w]+|[^\w]+ii$+|^ii$|^2[^\w]+|[^\w]+2$+|^2$|"
    regex3 = r"^iii[^\w]+|[^\w]+iii$+|^iii$|^3[^\w]+|[^\w]+3$+|^3$|"
    regex4 = r"^iv[^\w]+|[^\w]+iv$+|^iv$|^4[^\w]+|[^\w]+4$+|^4$|"
    regex5 = r"^v[^\w]+|[^\w]+v$+|^v$|^5[^\w]+|[^\w]+5$+|^5$|"
    regex6 = r"^vi[^\w]+|[^\w]+vi$+|^vi$|^6[^\w]+|[^\w]+6$+|^6$|"
    regex7 = r"^vii[^\w]+|[^\w]+vii$+|^vii$|^7[^\w]+|[^\w]+7$+|^7$|"
    regex8 = r"^viii[^\w]+|[^\w]+viii$+|^viii$|^8[^\w]+|[^\w]+8$+|^8$|"
    regex9 = r"^ix[^\w]+|[^\w]+ix$+|^ix$|^9[^\w]+|[^\w]+9$+|^9$|"
    regex10 = r"^x[^\w]+|[^\w]+x$+|^x$|^10[^\w]+|[^\w]+10$+|^10$"
    regex = regex1+regex2+regex3+regex4+regex5+regex6+regex7+regex8+regex9+regex10
    
    ack_index = -1
    if ACK2 != None:
        for i in range(len(lines)):
            if re.search(ACK2, lines[i],  re.IGNORECASE):
                ack_index = i
                break
        lines = lines[ack_index+1:]

    # remove every after page number(if page number exists)
    end_line = len(lines) 
    half_page_line = len(lines)//2 # the page number will must likes be between the bottom and half the page
    last_page_line = len(lines)-1
    for i in range(last_page_line, half_page_line, -1):
        if re.search(regex, lines[i]):
            #pdb.set_trace()
            end_line = i
            break
    return lines[:end_line]
    
def findAck(pdf_path = "./dissertation.pdf",from_page = 0,to_page = 29):
    """
    create a new pdf file from a subsection from pdf
    from_page(int): Where to start. Starts from 0.
    to_page(int): Where to end(inclusive).
    """
    pdf = PdfReader(pdf_path)
    num_pages = len(pdf.pages)
    if to_page > num_pages:
        to_page = num_pages-1
    ack_found = None
    ack_extracted, content_extracted = False, False
    acknowledgment = "Acknoledgement not present in file"
    for page_num in range(from_page, to_page):
        try: 
            pdfWriter = PdfWriter()
            pdfWriter.add_page(pdf.pages[page_num])   
            with open(f'./temp.pdf', 'wb') as temp:
                pdfWriter.write(temp)
            temp.close()
            content = convertToString().strip()
        except PyPDF2.errors.PdfReadError:
            return {"bool" : False, "content" :"PDF Broken"}
        if(ack_found == None):
            ACK = r'ack[n]?owledg[e]?ment[s]?\s*\n'
            ack_found = re.search(ACK,content, re.IGNORECASE)
        if(ack_found != None and ack_extracted == False):
            #pdb.set_trace()
            ACK2 = ack_found[0].split("\n")[0] 
            #find the index to find the index in lines
            
            try:
                ack_index = content.split("\n").index(ACK2)
            except ValueError:
                return {"bool" : False , "content" : "Error: Special case please review"}
            
            if ack_index > 4:
                ack_found = None
            else:
                acknowledgment =  content.strip()     
                lines = acknowledgment.split('\n')          
                lines = getAckFromLines(lines,ACK2)
                acknowledgment = "\n".join(lines)
                ack_extracted  = True
            continue # start loop again
        if(ack_extracted == True and content_extracted == False):
            #pdb.set_trace()
            lines = content.split('\n')
            next_title = lines[ack_index]
            words_of_next_title = next_title.split(" ")
            words_of_next_title = [i for i in words_of_next_title if i not in [""," "]]
            #pdb.set_trace()
            there_is_no_title = len(words_of_next_title) > 6
            if (there_is_no_title):   
                lines = content.strip().split('\n')          
                lines = getAckFromLines(lines)
                acknowledgment += "\n".join(lines)
                last_word = lines[-1]                    
            else:
                content_extracted = True
        if content_extracted == True:            
            return {"bool" : True, "content" :acknowledgment}
        
       
    return {"bool" : False, "content" :"ACKNOTFOUND"}

def convertToString():
    images = convert_from_path("./temp.pdf")
    content = ""
    images[0].save(f"./temp.jpg","JPEG")
    content = pytesseract.image_to_string(f"./temp.jpg")
    return content
import numpy as np
def Levenshtein(r, h):
    """                                                                         
    Calculation of WER with Levenshtein distance.                               
                                                                                
    Works only for iterables up to 254 elements (uint8).                        
    O(nm) time ans space complexity.                                            
                                                                                
    Parameters                                                                  
    ----------                                                                  
    r : list of strings                                                                    
    h : list of strings                                                                   
                                                                                
    Returns                                                                     
    -------                                                                     
    (WER, nS, nI, nD): (float, int, int, int) WER, number of substitutions, insertions, and deletions respectively
                                                                                
    Examples                                                                    
    --------                                                                    
    >>> wer("who is there".split(), "is there".split())                         
    0.333 0 0 1                                                                           
    >>> wer("who is there".split(), "".split())                                 
    1.0 0 0 3                                                                           
    >>> wer("".split(), "who is there".split())      #ask in Pia
    Inf 0 3 0                                                                           
    """

    n = len(r) # The number of words in REF
    m = len(h) # The number of words in HYP
    R = np.zeros((n+1,m+1))
    B = np.zeros((n+1,m+1))

    #for all i,j s.t.  i = 0 or  j = 0,	set	R[i,j] ← max (i,j) end
    R[0,:] = np.arange(m+1)
    R[:,0] = np.arange(n+1)
    # i think we should do this aswell
    up = 0
    left = 1
    up_left = 2
    up_left2 = 3
    B[0,:] = left
    B[:,0] = up
    B[0,0] = up
    for i in range(1,n+1):
        for j in range(1,m+1):
            dele = R[i - 1, j] + 1 # delete
            sub = R[i - 1, j - 1] + (1,0)[r[i-1] == h[j-1]] #substitute #NOTE look at this
            ins = R[i, j-1] + 1 #insert

            R[i,j] = min(dele,sub,ins)
            if R[i,j] == dele:
                B[i , j] = up
            elif R[i , j] == ins:
                B[i,j] = left
            else:
                B[i,j] = (up_left, up_left2 )[r[i-1] == h[j-1]]
    i,j = n,m
    nSub,nDel,nIns = 0, 0, 0
    transversal = True
    while transversal == True:
        path = B[i,j]
        if i <=  0 and j <=0:
            transversal = False
            break
        if path == up_left:
            i -= 1
            j -= 1
            nSub += 1
        elif path == left:
            j -= 1
            nIns +=1
        elif path == up:
            i -= 1
            nDel +=1
        else: # correct
            i -= 1
            j -= 1
    return R[n,m]/n, nSub, nIns, nDel        
    
def getAcknoledgement(page,pages):
    """
    Rule:
    1. Look for the first occurcance of Acknowledgments and a new line.
    2. Caputure the content until you hit the title of the next section  
    #ASSUMPTIONS that the dissertations need to follow.
    #1. Every dissertation starts it's acknoledgement with the word "Acknoledgement" as the only word in it's title
    #2. No two titles can occupy the same page. 
    #3. The acknoledgement starts with a capital letter (i.e Acknoledgement)
    #4. The title acknoledgemen may or may not end an s.
    #5. If a line has 1 to 6 words in it. Then it's a title of a new section.
    #6. Titles are located on the same location on each page.i.e top and centre
    #7. Each word is of average size(6 chars long)
    #8. Target titles can either be Acknowledgments or acknowledg(e)ments
    #9. The Acknoledgemts page doesn't have picture/images
    #10. Acknoledgements are never in the first page
    Params: 
    page : pdfplumber.page.Page
    returns(String) :The content of the abstraction
    """    
    initial_index = page.page_number -1
    content = page.extract_text()
    if(content is None): return None
    content = content.strip()
    ACK = r'ack[n]?owledg[e]?ment[s]?\s*\n'
    ack_found = re.search(ACK,content, re.IGNORECASE)
    title_len = len(ACK)
    acknowledgment = None
    #if Acknowledgement is the title extract it else continue
    if(ack_found):
        #pdb.set_trace()
        ACK2 = ack_found[0].split("\n")[0] 
        acknowledgment =  content.strip()     
        lines = acknowledgment.split('\n')          
        lines = getAckFromLines(lines,ACK2)
        acknowledgment = "\n".join(lines)        
        stop_not_true = True
        #find the index to find the index in lines
        try:
            ack_line = content.strip().split("\n")
            ack_index = ack_line.index(ACK2)
            ack_line = [ack_line[i] for i in range(ack_index+1) if i not in ["", " "]]
            ack_index = ack_line.index(ACK2)
        except ValueError:
            return "Error: Special case please revuew"
        counter = 1
        while(stop_not_true):
            next_page = counter + initial_index
            #pdb.set_trace()
            page = pages[next_page]
            content = page.extract_text().lower().lstrip()
            lines = content.split('\n')
            next_title = lines[ack_index]
            words_of_next_title = next_title.split(" ")
            words_of_next_title = [i for i in words_of_next_title if i not in [""," "]]
            #pdb.set_trace()
            there_is_no_title = len(words_of_next_title) > 6
            if (there_is_no_title):   
                lines = content.strip().split('\n')          
                lines = getAckFromLines(lines)
                acknowledgment += "\n".join(lines)
                last_word = lines[-1]                    
                counter+=1
            else:
                stop_not_true = False
    return acknowledgment

def findAck2(pdf_path = "./dissertation.pdf",from_page = 0,to_page = 29):
    with pdfplumber.open(pdf_path, strict_metadata=True) as pdf:
        pages = iter(pdf.pages)
        count = 0
        
        for page in pages:
            count +=1
            if count >= from_page: 
                content = page.extract_text()        
                acknowledgement = getAcknoledgement(page, pdf.pages)    
                if(acknowledgement != None):
                    if("(cid:" in acknowledgement):
                        acknowledgement = "ERROR: It contains embedded fonts. This requires revisitation."
                        
                    return {"bool": True ,  "content": acknowledgement}
            if page.page_number == to_page:
                print("ack not found")
                return {"bool": False, "content":"ACKNOTFOUND"  }
            

def compare(ack1,ack2):
    if(ack1['bool'] == True and ack2['bool']  == True ):
        content1 = ack1["content"].replace("\n", "").strip().split()
        content2 = ack2["content"].replace("\n", "").strip().split()
        WER = Levenshtein(content1, content2)[0]
        print(WER)
        if(WER < 0.2):
            return ack1["content"], "N/A: same as 1st parser"          
    return ack1["content"] , ack2["content"]


def main_alt():
    """Shows basic usage of the Sheets API.
    Prints values from a sample spreadsheet.
    """
    # If modifying these scopes, delete the file token.json.
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())            
    return creds

def main():
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/cloud-platform']
    SERVICE_ACCOUNT_FILE = '../Keys/simpeapis-ff416f56b1c4.json' 

    credentials = service_account.Credentials.from_service_account_file(
            SERVICE_ACCOUNT_FILE, scopes=SCOPES)
    return credentials
    
creds = main()
service = build('sheets', 'v4', credentials=creds)

def send_pdf_link(data, count, service):
    
    authorNtitle_body = {
        "majorDimension" : "ROWS",
        "values" : 
            [
            [data['author'],data['title']],
            ]
    }

    authorNtitle_cells = f"A{count+1}:B{count+1}"

    # have a program that send s batch as oppossed to just one
    sheet = service.spreadsheets()
    post_authorNtitle = sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                          range = authorNtitle_cells,
                          valueInputOption ='RAW',
                          includeValuesInResponse = True,
                          body =  authorNtitle_body )

    pdf_link_body = {
        "majorDimension" : "ROWS",
        "values" : 
            [
            [data['pdf_link']],
            ]
    }

    pdf_link_cells = f"E{count+1}"  

    post_pdf_link = sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                          range = pdf_link_cells,
                          valueInputOption ='RAW',
                          includeValuesInResponse = True,
                          body =  pdf_link_body )       

    try:
        post_authorNtitle.execute()
        post_pdf_link.execute()
        return 
    except ConnectionResetError:
        print("ConnectionResetError")

s = Service("/Users/oluwaseuncardoso/Downloads/chromedriver")
driver = webdriver.Chrome(service = s)

#12-i#VFZ4eVWZ8fq6V

# %% [markdown]
# # Go to specific page
# Play the tab below and answer the questions below.

# %%
driver.get("https://www.proquest.com/")
print("What page do you want to go to: ")
page = int(input())

print("How many pages per page do you want to see 10, 20, 50, 100: ")
items_per_page = int(input())

print(f"Pick a range from 1 - {items_per_page} for where you want to start downloading")
start = int(input())
  
try:
    elem = driver.find_element(By.ID,"queryTermField")  
except  NoSuchElementException:
    elem = driver.find_element(By.ID,"searchTerm")
elem.clear()
elem.send_keys("STYPE(DISSERTATION) AND PD(2010-2016) AND DEP.X(PSYCHOLOGY) AND LA(ENGLISH) AND DG(PHD) AND (ULO(UNITED STATES))  NOT SU(CLINICAL)")
elem.send_keys(Keys.RETURN)
sleep(10)

dropdown = Select(driver.find_element(By.ID,"itemsPerPage"))
dropdown.select_by_value(str(items_per_page))
sleep(10)

search = driver.find_element(By.ID,"pageNbrField") 
search.clear()
search.send_keys(str(page))
search.send_keys(Keys.RETURN)

sleep(10)

html = driver.execute_script("return document.documentElement.outerHTML;")
bs = BeautifulSoup(html, "html5lib")
results = bs.find_all(attrs= {"class": "resultItem ltr"})
h1 = bs.find_all( "h1")[0]
num_results = h1.contents[0]
num_results = num_results.strip()
num_results = num_results.replace(',', "")
num_results = re.search(r'[0-9]*', num_results)
num_results = int(num_results[0])
next_page = bs.find_all("a", attrs = {"title" : "Next Page"} )
count = (page -1) * items_per_page + start
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 driver.get("https://www.proquest.com/")
#       2 print("What page do you want to go to: ")
#       3 page = int(input())
#
# NameError: name 'driver' is not defined

# %%
#import undetected_chromedriver  as webdriver

o = webdriver.ChromeOptions()
#adding specific Chrome Profile Path
o.add_arguments = {'user-data-dir':'/Users/profq/Library/Application Support/Google/Chrome/Profile 1'}
#set chromedriver.exe path
driver = webdriver.Chrome(service = s, options=o)
#maximize browser
driver.maximize_window()
#launch URL
driver.get("https://www.proquest.com")
#get browser title
print(driver.title)
#close browser
#driver.close()
# Out:
# ProQuest | Better research, better learning, better insights.

# %%
pickle.dump(driver.get_cookies(), open("cookies.pkl", "wb"))
#driver.close()

# %%
#driver1.delete_all_cookies()
driver1.get_cookies()
# Out:
# [{'domain': '.uwaterloo.ca',
#   'expiry': 1680051726,
#   'httpOnly': False,
#   'name': '_fbp',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'fb.1.1672275725206.1701385484'},
#  {'domain': '.uwaterloo.ca',
#   'expiry': 1672275786,
#   'httpOnly': False,
#   'name': '_gat_UA-51776731-14',
#   'path': '/',
#   'secure': False,
#   'value': '1'},
#  {'domain': '.uwaterloo.ca',
#   'httpOnly': True,
#   'name': 'SSESSe7f79aea29d14e4558d7263d447d249c',
#   'path': '/',
#   'secure': True,
#   'value': '1DrZdds20qTEp4c6Treur0ptqLMVPmcALskt5KUfmvM'},
#  {'domain': '.uwaterloo.ca',
#   'expiry': 1706835726,
#   'httpOnly': False,
#   'name': '_ga',
#   'path': '/',
#   'secure': False,
#   'value': 'GA1.2.1115898832.1672272946'},
#  {'domain': '.uwaterloo.ca',
#   'expiry': 1672275782,
#   'httpOnly': False,
#   'name': '_gat_tracker0',
#   'path': '/',
#   'secure': False,
#   'value': '1'},
#  {'domain': '.uwaterloo.ca',
#   'expiry': 1706835726,
#   'httpOnly': False,
#   'name': '_ga_W3BFRPSG9B',
#   'path': '/',
#   'secure': False,
#   'value': 'GS1.1.1672275724.1.0.1672275726.58.0.0'},
#  {'domain': 'uwaterloo.ca',
#   'httpOnly': False,
#   'name': 'has_js',
#   'path': '/',
#   'secure': False,
#   'value': '1'},
#  {'domain': '.uwaterloo.ca',
#   'expiry': 1672362126,
#   'httpOnly': False,
#   'name': '_gid',
#   'path': '/',
#   'secure': False,
#   'value': 'GA1.2.1034285027.1672272946'},
#  {'domain': '.uwaterloo.ca',
#   'expiry': 1680051722,
#   'httpOnly': False,
#   'name': '_gcl_au',
#   'path': '/',
#   'secure': False,
#   'value': '1.1.2016470069.1672275722'},
#  {'domain': '.uwaterloo.ca',
#   'expiry': 1672275782,
#   'httpOnly': False,
#   'name': '_gat_UA-51776731-1',
#   'path': '/',
#   'secure': False,
#   'value': '1'},
#  {'domain': '.uwaterloo.ca',
#   'expiry': 1706833357,
#   'httpOnly': False,
#   'name': '_ga_2P8HJFC42V',
#   'path': '/',
#   'secure': True,
#   'value': 'GS1.1.1672273357.1.0.1672273357.0.0.0'}]

# %%
with open("cookies.pkl", "rb") as f:
    cookies = pickle.load(f)
    cookie = cookies[0]
    print(len(cookies))

for i in cookies:
    print(i)
# Out:
# 16
# {'domain': '.www-proquest-com.proxy.lib.uwaterloo.ca', 'expiry': 1703809357, 'httpOnly': False, 'name': 'OptanonAlertBoxClosed', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '2022-12-29T00:22:37.184Z'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'availability-zone', 'path': '/', 'secure': False, 'value': 'us-east-1f'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'oneSearchTZ', 'path': '/', 'secure': False, 'value': '-300'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': True, 'name': 'AWSELB', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '4B59AF0D188D3D5EEA91D28C1799E3F4C2857430263B66E1B6BF1CA8A7BFAB21DAC62F5EE511C003C89FF9F76787C1284A401F41B0A1030A8E6463DE6F5DEBF2553FB6C834BB7810A24235415383E9FCC2D428E2EE'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'osTimestamp', 'path': '/', 'secure': False, 'value': '1672273350.214'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'AppVersion', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': 'r2022.11.0.4613'}
# {'domain': '.uwaterloo.ca', 'expiry': 1706833357, 'httpOnly': False, 'name': '_ga', 'path': '/', 'secure': False, 'value': 'GA1.1.1115898832.1672272946'}
# {'domain': '.uwaterloo.ca', 'expiry': 1706833357, 'httpOnly': False, 'name': '_ga_2P8HJFC42V', 'path': '/', 'secure': False, 'value': 'GS1.1.1672273357.1.0.1672273357.0.0.0'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': True, 'name': 'JSESSIONID', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '74392F74967364877BAC75A03B716713.i-0eeb985cbe78280cb'}
# {'domain': '.uwaterloo.ca', 'expiry': 1672359757, 'httpOnly': False, 'name': '_gid', 'path': '/', 'secure': False, 'value': 'GA1.2.1034285027.1672272946'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'expiry': 1672877992, 'httpOnly': False, 'name': 'authSub', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '1'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'expiry': 1680913192, 'httpOnly': False, 'name': 'authenticatedBy', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': 'IP'}
# {'domain': '.lib.uwaterloo.ca', 'httpOnly': True, 'name': 'ezproxyn', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': 'NDc1IEEdqex8Ee4'}
# {'domain': '.www-proquest-com.proxy.lib.uwaterloo.ca', 'expiry': 1703809357, 'httpOnly': False, 'name': 'OptanonConsent', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': 'isGpcEnabled=0&datestamp=Wed+Dec+28+2022+19%3A22%3A37+GMT-0500+(Eastern+Standard+Time)&version=6.36.0&isIABGlobal=false&hosts=&consentId=a5407518-1b8a-4bd6-802b-efe553516e64&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1%2CC0005%3A1%2CC0002%3A1'}
# {'domain': '.lib.uwaterloo.ca', 'httpOnly': True, 'name': 'ezproxyl', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': 'NDc1IEEdqex8Ee4'}
# {'domain': '.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'ezproxy', 'path': '/', 'secure': False, 'value': 'NDc1IEEdqex8Ee4'}

# %%
for cookie in cookies:
    print(cookie)
    if cookie['domain'] == '.uwaterloo.ca':
        driver1.add_cookie(cookie)
# Out:
# {'domain': '.www-proquest-com.proxy.lib.uwaterloo.ca', 'expiry': 1703809357, 'httpOnly': False, 'name': 'OptanonAlertBoxClosed', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '2022-12-29T00:22:37.184Z'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'availability-zone', 'path': '/', 'secure': False, 'value': 'us-east-1f'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'oneSearchTZ', 'path': '/', 'secure': False, 'value': '-300'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': True, 'name': 'AWSELB', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '4B59AF0D188D3D5EEA91D28C1799E3F4C2857430263B66E1B6BF1CA8A7BFAB21DAC62F5EE511C003C89FF9F76787C1284A401F41B0A1030A8E6463DE6F5DEBF2553FB6C834BB7810A24235415383E9FCC2D428E2EE'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'osTimestamp', 'path': '/', 'secure': False, 'value': '1672273350.214'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'AppVersion', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': 'r2022.11.0.4613'}
# {'domain': '.uwaterloo.ca', 'expiry': 1706833357, 'httpOnly': False, 'name': '_ga', 'path': '/', 'secure': False, 'value': 'GA1.1.1115898832.1672272946'}
# {'domain': '.uwaterloo.ca', 'expiry': 1706833357, 'httpOnly': False, 'name': '_ga_2P8HJFC42V', 'path': '/', 'secure': False, 'value': 'GS1.1.1672273357.1.0.1672273357.0.0.0'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'httpOnly': True, 'name': 'JSESSIONID', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '74392F74967364877BAC75A03B716713.i-0eeb985cbe78280cb'}
# {'domain': '.uwaterloo.ca', 'expiry': 1672359757, 'httpOnly': False, 'name': '_gid', 'path': '/', 'secure': False, 'value': 'GA1.2.1034285027.1672272946'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'expiry': 1672877992, 'httpOnly': False, 'name': 'authSub', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '1'}
# {'domain': 'www-proquest-com.proxy.lib.uwaterloo.ca', 'expiry': 1680913192, 'httpOnly': False, 'name': 'authenticatedBy', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': 'IP'}
# {'domain': '.lib.uwaterloo.ca', 'httpOnly': True, 'name': 'ezproxyn', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': 'NDc1IEEdqex8Ee4'}
# {'domain': '.www-proquest-com.proxy.lib.uwaterloo.ca', 'expiry': 1703809357, 'httpOnly': False, 'name': 'OptanonConsent', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': 'isGpcEnabled=0&datestamp=Wed+Dec+28+2022+19%3A22%3A37+GMT-0500+(Eastern+Standard+Time)&version=6.36.0&isIABGlobal=false&hosts=&consentId=a5407518-1b8a-4bd6-802b-efe553516e64&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1%2CC0005%3A1%2CC0002%3A1'}
# {'domain': '.lib.uwaterloo.ca', 'httpOnly': True, 'name': 'ezproxyl', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': 'NDc1IEEdqex8Ee4'}
# {'domain': '.lib.uwaterloo.ca', 'httpOnly': False, 'name': 'ezproxy', 'path': '/', 'secure': False, 'value': 'NDc1IEEdqex8Ee4'}

# %% [markdown]
# # Scrapping

# %%
import csv
Error = "Does not exist in this dissertation"

while count <= num_results:
    print(f"starting downloads at page:{page}")
    print("---------------------------")

    for index in range(start-1, len(results)):
        if index % 10 == 0:
            multiplier = np.random.randint(1,10,1)[0]
            print(f"Time waiting: {multiplier*10 } seconds")
            sleep(multiplier * 10)
        data = {'ack1':Error, 'ack2': Error}
        cell = f"A{count+1}:D{count+1}"
        result = results[index]
        link = result.find(attrs = {"contentArea"}).find("a")["href"]
        bs = getBs(link)    
        div = result.find_all("div", attrs= {"class": "truncatedResultsTitle"})[0]
        
        
        data['title'] = "".join([str(i) for i in bs.find_all("h1", attrs= {"class": "documentTitle"})[0].contents])
        # find author
        spans = result.find_all("span", attrs= {"class": "truncatedAuthor"})
        data['author'] = spans[0].contents[0].replace(".\xa0\n","")
        try:
            pdf = bs.find(attrs = {"download":"ProQuestDocument.pdf"})["href"]
        except TypeError:           
            span = bs.find_all(lambda tag:findLink(tag))
            if(len(span) != 0):
                link = span.a["href"]
                bs = getBs(link) 
                pdf = bs.find(attrs = {"download":"ProQuestDocument.pdf"})["href"]
            else:
                print("Couln't download PDF")
                # find title

        data['pdf_link'] = pdf
        
        send_pdf_link(data,count,service)
        
        print(pdf)
        title = data['title']         
        print(f'pdf: {count}, cell: {cell} title:{title} ') 
        count +=1
               
    if len(next_page) == 1: # there is a next page
        page+=1
        print(f'going to next page')
        next_page_link = next_page[0]['href']
        bs = getBs(next_page_link)
        results = bs.find_all(attrs= {"class": "resultItem ltr"}) 
    next_page = bs.find_all("a", attrs = {"title" : "Next Page"} )
    start = 1
# Out:
# starting downloads at page:7
# ---------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 17
#      15 result = results[index]
#      16 link = result.find(attrs = {"contentArea"}).find("a")["href"]
# ---> 17 bs = getBs(link)
#      18 div = result.find_all("div", attrs= {"class": "truncatedResultsTitle"})[0]
#      21 data['title'] = "".join([str(i) for i in bs.find_all("h1", attrs= {"class": "documentTitle"})[0].contents])
#
# Cell In[18], line 56, in getBs(link)
#      51 def getBs(link):
#      52     """
#      53     This function takes a proquest Url
#      54     and returns the beautiful soup object
#      55     """
# ---> 56     driver.get(link)
#      57     sleep(3)
#      58     html = driver.execute_script("return document.documentElement.outerHTML;")
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.execute(self, driver_command, params)
#     439     elif "sessionId" not in params:
#     440         params["sessionId"] = self.session_id
# --> 442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
#     444     self.error_handler.check_response(response)
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:316, in RemoteConnection._request(self, method, url, body)
#     313     body = None
#     315 if self.keep_alive:
# --> 316     response = self._conn.request(method, url, body=body, headers=headers)
#     317     statuscode = response.status
#     318 else:
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Desktop/Projects/PythonProjects/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /usr/local/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /usr/local/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
count, num_results, start
# Out:
# (693, 6391, 52)

# %%
start = 52

# %%
from_page = 0
to_page = 29
pdf = PdfReader(pdf_path)
num_pages = len(pdf.pages)
if to_page > num_pages:
    to_page = num_pages-1
ack_found = None
ack_extracted, content_extracted = False, False
acknowledgment = "Acknoledgement not present in file"
for page_num in range(from_page, to_page):
    try: 
        pdfWriter = PdfWriter()
        pdfWriter.add_page(pdf.pages[page_num])   
        with open(f'./temp.pdf', 'wb') as temp:
            pdfWriter.write(temp)
        temp.close()
        content = convertToString().strip()
    except PyPDF2.errors.PdfReadError:
        print({"bool" : False, "content" :"PDF Broken"})
#     if(ack_found == None):
#         ACK = r'ack[n]?owledg[e]?ment[s]?\s*\n'
#         ack_found = re.search(ACK,content, re.IGNORECASE)
#     if(ack_found != None and ack_extracted == False):
#         #pdb.set_trace()
#         ACK2 = ack_found[0].split("\n")[0] 
#         #find the index to find the index in lines

# %% [markdown]
# # Parse Affiliations

# %%
def getAffiliate(cells):
    result = service.spreadsheets().values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID, range=cells).execute()
    rows = result.get('values', [])
    rows = [i[0] for i in rows]
    return rows

# %%
import csv
Error = "Does not exist in this dissertation"
affiliations, authors = [], []
while count <= num_results:
    print(f"starting downloads at page:{page}")
    print("---------------------------")
    for index in range(start-1, len(results)):
        data = {'ack1':Error, 'ack2': Error}
        cell = f"A{count+1}:D{count+1}"
        result = results[index]      
        
        spans = result.find_all("span", attrs= {"class": "titleAuthorETC"})
        author = spans[0].contents[0].replace(".\xa0\n","")
        affiliation = spans[1].contents[0]
        content = re.search(r'[a-zA-Z\s-,()]*',affiliation)
        affiliation = content[0]
        authors.append(author)
        affiliations.append(affiliation)
        count +=1
    if len(next_page) == 1: # there is a next page
        page+=1
        print(f'going to next page')
        next_page_link = next_page[0]['href']
        bs = getBs(next_page_link)
        results = bs.find_all(attrs= {"class": "resultItem ltr"}) 
    next_page = bs.find_all("a", attrs = {"title" : "Next Page"} )
    start = 1
# Out:
# starting downloads at page:1
# ---------------------------
# going to next page
# starting downloads at page:2
# ---------------------------
# going to next page
# starting downloads at page:3
# ---------------------------
# going to next page
# starting downloads at page:4
# ---------------------------
# going to next page
# starting downloads at page:5
# ---------------------------
# going to next page
# starting downloads at page:6
# ---------------------------
# going to next page
# starting downloads at page:7
# ---------------------------
# going to next page
# starting downloads at page:8
# ---------------------------
# going to next page
# starting downloads at page:9
# ---------------------------
# going to next page
# starting downloads at page:10
# ---------------------------
# going to next page
# starting downloads at page:11
# ---------------------------
# going to next page
# starting downloads at page:12
# ---------------------------

# %%
# !brew install poppler
# Out:
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# agg                                      lmfit
# akku                                     luacheck
# ansible@6                                lucky-commit
# antidote                                 macpine
# apophenia                                mailsy
# aribb24                                  mariadb@10.8
# autocorrect                              mariadb@10.9
# bazarr                                   markdownlint-cli2
# bdftopcf                                 marksman
# berkeley-db@5                            mesheryctl
# bindgen                                  metals
# brpc                                     metview
# btrfs-progs                              mimirtool
# buf                                      mqttui
# burst                                    muon
# busted                                   mxnet
# c                                        mycorrhiza
# c2rust                                   naga-cli
# camlp-streams                            nap
# cargo-crev                               nemu
# cargo-depgraph                           netcdf-cxx
# cargo-zigbuild                           netcdf-fortran
# cbindgen                                 node@18
# cdsclient                                nuraft
# censys                                   oauth2c
# chain-bench                              objconv
# clitest                                  onlykey-agent
# cloudflare-wrangler2                     open62541
# cloudprober                              opencl-icd-loader
# clusterawsadm                            osv-scanner
# cmctl                                    ouch
# cntb                                     page
# cocogitto                                pandemics
# code-cli                                 pbzx
# cog                                      pdf-diff
# commitlint                               pferd
# conda-zsh-completion                     pgsync
# corrosion                                php@8.1
# countdown                                pinocchio
# cpp-httplib                              pint
# cpuid                                    pkcs11-tools
# cql-proxy                                pluto
# create-api                               pomsky
# crytic-compile                           popeye
# curlcpp                                  portablegl
# d2                                       postgresql@15
# distrobox                                protolint
# dotnet@6                                 prowler
# dronedb                                  proxsuite
# dsda-doom                                prql-compiler
# dufs                                     prr
# dura                                     psysh
# dynein                                   purescript-language-server
# echidna                                  pymol
# edencommon                               pymupdf
# emqx                                     python-gdbm@3.11
# enex2notion                              python-lsp-server
# enpass-cli                               python-tk@3.11
# envd                                     python-typing-extensions
# erigon                                   python@3.11
# evtx                                     pyyaml
# fastfetch                                quilt-installer
# felinks                                  rdb
# fend                                     retdec
# ferium                                   ripsecrets
# fonts-encodings                          rnr
# fortls                                   rome
# fred                                     ruff
# fuego-firestore                          rush-parallel
# gator                                    sambamba
# gaze                                     sapling
# gcc@11                                   scala@2.13
# gcem                                     schemathesis
# gdrive-downloader                        secp256k1
# gebug                                    seven-kingdoms
# gf                                       sgr
# ghc@8.10                                 shaderc
# ghc@9.2                                  skaffold@1.39
# ghorg                                    skeema
# git-delete-merged-branches               slither-analyzer
# git-machete                              smap
# git-sync                                 snakefmt
# go-camo                                  snapcast
# go-task                                  sniffnet
# go@1.18                                  snowball
# gobackup                                 socket_vmnet
# got                                      solc-select
# grammarly-languageserver                 souffle
# grantlee                                 spectral-cli
# graphqxl                                 speedbump
# gum                                      sql-language-server
# has                                      sqlcmd
# hermit                                   standard
# highway                                  steampipe
# hof                                      stepci
# hotbuild                                 stuffbin
# hpp-fcl                                  stylelint
# httm                                     svt-av1
# huggingface-cli                          swiftdraw
# hysteria                                 syft
# hyx                                      syslog-ng
# ibazel                                   taplo
# iir1                                     tart
# jj                                       tbls
# joker                                    temporal
# jscpd                                    tere
# json2tsv                                 textract
# jupp                                     tfel
# kalign                                   tlsx
# keploy                                   toml-test
# kubefirst                                totp-cli
# kubesess                                 tproxy
# kubevious                                trezor-bridge
# kustomizer                               tuntox
# libdivide                                tut
# libeatmydata                             txt2man
# libemf2svg                               typewritten
# libff                                    typos-cli
# libfyaml                                 unxip
# libgrapheme                              valijson
# libisofs                                 verovio
# liblbfgs                                 vhs
# libplacebo                               vineyard
# libretls                                 wasm-micro-runtime
# libunibreak                              waybackpy
# liburing                                 weasyprint
# libvatek                                 wikibase-cli
# license-eye                              x86_64-linux-gnu-binutils
# licensed                                 xcodes
# licenseplist                             xctesthtmlreport
# linux-headers@5.15                       xq
# llama                                    xwin
# llvm@14                                  zf
# ==> New Casks
# 86box                                    micromamba
# adze                                     mints
# agi                                      mixin
# akiflow                                  moderndeck
# aliwangwang                              nanoem
# ankerslicer                              neat
# ankerwork                                northern-softworks-cache-cleaner
# anytype                                  notesnook
# apifox                                   onekey
# apipost                                  openlens
# aptakube                                 opensoundmeter
# arc                                      orka-vm-tools
# arduino-ide                              overt
# ares                                     paper
# attachecase                              picfindr
# bambu-studio                             pictureview
# battery                                  pieces-cli
# beast2                                   planet
# binocs                                   playcover-community
# bluebubbles                              plugdata
# blurscreen                               polypad
# bookwright                               postman-cli
# bridge                                   prismlauncher
# buzz                                     protonmail-import-export
# cad-assistant                            qspace-pro
# chipmunk                                 quiet-reader
# chromium-gost                            qwerty-fr
# cider                                    random-mouse-clicker
# cisdem-duplicate-finder                  rapidapi
# clickshare                               readdle-spark
# color-studio                             readmoreading
# cursr                                    reflect
# dbeaverlite                              reflex
# dbeaverultimate                          restfox
# dcp-o-matic-editor                       reverso
# decentr                                  rnnoise
# devcleaner                               sanesidebuttons
# devsquadron                              scene-maestro
# diffusionbee                             scenica-player
# doll                                     scrolla
# douyin                                   shop-different
# duckduckgo                               slab
# duplicacy-cli                            slack-cli
# elephas                                  sms-plus
# eloquent                                 snapmaker-luban
# farcaster                                spike
# filen                                    spline
# finch                                    superkey
# fleet                                    tageditor
# fresh                                    tempbox
# gamemaker                                texifier
# genesis-plus                             thangs-sync
# gittyup                                  tl-legacy
# glance-chamburr                          topaz-denoise-ai
# go-shiori                                topaz-gigapixel-ai
# goxel                                    topaz-sharpen-ai
# height                                   topaz-video-ai
# hookmark                                 trunk-io
# httpie                                   tsh
# icon-shelf                               typcn-bilibili
# iconchanger                              unite-phone
# imhex                                    unraid-usb-creator
# iqmol                                    v2ray-unofficial
# keet                                     vero
# kigb                                     vincelwt-chatgpt
# kopiaui                                  virtual-desktop-streamer
# laconvolver                              virtualbuddy
# languagetool                             vk-calls
# lectrote                                 watchfacestudio
# livebook                                 wooshy
# lookingglassbridge                       workman
# lookingglassstudio                       workspace-one-intelligent-hub
# lunacy                                   xprocheck
# macforge                                 youtype
# menubarx                                 yubihsm2-sdk
#
# You have 59 outdated formulae and 1 outdated cask installed.
# You can upgrade them with brew upgrade
# or list them with brew outdated.
#
# ==> Fetching dependencies for poppler: libpng, fontconfig, pcre2, gettext, glib, xorgproto, libxau, libxdmcp, libx11, libxext, pixman, jpeg-turbo, lz4, xz, libtiff, little-cms2, nspr and nss
# ==> Fetching libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.39
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:f7217880961
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.14.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:e910d78
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching pcre2
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/manifests/10.42
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/blobs/sha256:76ccbd45954e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching gettext
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.21.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/blobs/sha256:9318777367
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching glib
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.74.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:6ea384ecf3942
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching xorgproto
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2022.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:d6deb2e4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libxau
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.11
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:3b8790c3aaf
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libxdmcp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:16a26bf97
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libx11
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:cbaa4ea2113
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libxext
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:9682e4720a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching pixman
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.42.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:f7c0d1f71dd
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/2.1.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:d2d17e1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching lz4
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:88b369cea90a0a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.4.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/blobs/sha256:49097bc9869e9ab
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.4.0_1-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:f110c775f8
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.14
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:57a938
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching nspr
# ==> Downloading https://ghcr.io/v2/homebrew/core/nspr/manifests/4.35
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nspr/blobs/sha256:7b4bd4b9800ba
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching nss
# ==> Downloading https://ghcr.io/v2/homebrew/core/nss/manifests/3.86
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nss/blobs/sha256:814c110786ea23
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching poppler
# ==> Downloading https://ghcr.io/v2/homebrew/core/poppler/manifests/22.12.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/poppler/blobs/sha256:a2b52746a5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Installing dependencies for poppler: libpng, fontconfig, pcre2, gettext, glib, xorgproto, libxau, libxdmcp, libx11, libxext, pixman, jpeg-turbo, lz4, xz, libtiff, little-cms2, nspr and nss
# ==> Installing poppler dependency: libpng
# ==> Pouring libpng--1.6.39.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libpng/1.6.39: 27 files, 1.3MB
# ==> Installing poppler dependency: fontconfig
# ==> Pouring fontconfig--2.14.1.monterey.bottle.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /usr/local/Cellar/fontconfig/2.14.1/bin/fc-cache -frv
# 🍺  /usr/local/Cellar/fontconfig/2.14.1: 88 files, 2.3MB
# ==> Installing poppler dependency: pcre2
# ==> Pouring pcre2--10.42.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/pcre2/10.42: 230 files, 6.4MB
# ==> Installing poppler dependency: gettext
# ==> Pouring gettext--0.21.1.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/gettext/0.21.1: 1,983 files, 20.6MB
# ==> Installing poppler dependency: glib
# ==> Pouring glib--2.74.4.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/glib/2.74.4: 449 files, 20.9MB
# ==> Installing poppler dependency: xorgproto
# ==> Pouring xorgproto--2022.2.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/xorgproto/2022.2: 268 files, 3.9MB
# ==> Installing poppler dependency: libxau
# ==> Pouring libxau--1.0.11.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxau/1.0.11: 21 files, 105.5KB
# ==> Installing poppler dependency: libxdmcp
# ==> Pouring libxdmcp--1.1.4.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxdmcp/1.1.4: 11 files, 113.8KB
# ==> Installing poppler dependency: libx11
# ==> Pouring libx11--1.8.2.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libx11/1.8.2: 1,054 files, 7.0MB
# ==> Installing poppler dependency: libxext
# ==> Pouring libxext--1.3.5.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxext/1.3.5: 87 files, 426.9KB
# ==> Installing poppler dependency: pixman
# ==> Pouring pixman--0.42.2.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/pixman/0.42.2: 11 files, 1.3MB
# ==> Installing poppler dependency: jpeg-turbo
# ==> Pouring jpeg-turbo--2.1.4.monterey.bottle.tar.gz
# Warning: These files were overwritten during the `brew link` step:
# /usr/local/bin/cjpeg
# /usr/local/bin/djpeg
# /usr/local/bin/jpegtran
# /usr/local/bin/rdjpgcom
# /usr/local/bin/wrjpgcom
# /usr/local/include/jconfig.h
# /usr/local/include/jerror.h
# /usr/local/include/jmorecfg.h
# /usr/local/include/jpeglib.h
# /usr/local/share/man/man1/cjpeg.1
# /usr/local/share/man/man1/djpeg.1
# /usr/local/share/man/man1/jpegtran.1
# /usr/local/share/man/man1/rdjpgcom.1
# /usr/local/share/man/man1/wrjpgcom.1
# /usr/local/lib/libjpeg.a
# /usr/local/lib/libjpeg.dylib
# /usr/local/lib/pkgconfig/libjpeg.pc
#
# They have been backed up to: /Users/profq/Library/Caches/Homebrew/Backup
# ==> Summary
# 🍺  /usr/local/Cellar/jpeg-turbo/2.1.4: 44 files, 3.8MB
# ==> Installing poppler dependency: lz4
# ==> Pouring lz4--1.9.4.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/lz4/1.9.4: 22 files, 685.2KB
# ==> Installing poppler dependency: xz
# ==> Pouring xz--5.4.0.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/xz/5.4.0: 95 files, 1.6MB
# ==> Installing poppler dependency: libtiff
# ==> Pouring libtiff--4.4.0_1.monterey.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/libtiff/4.4.0_1: 249 files, 4.5MB
# ==> Installing poppler dependency: little-cms2
# ==> Pouring little-cms2--2.14.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/little-cms2/2.14: 21 files, 1.3MB
# ==> Installing poppler dependency: nspr
# ==> Pouring nspr--4.35.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/nspr/4.35: 86 files, 1.2MB
# ==> Installing poppler dependency: nss
# ==> Pouring nss--3.86.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/nss/3.86: 211 files, 18.1MB
# ==> Installing poppler
# ==> Pouring poppler--22.12.0.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/poppler/22.12.0: 464 files, 28MB
# ==> Running `brew cleanup poppler`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Upgrading 21 dependents of upgraded formulae:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# aom 3.4.0 -> 3.5.0_1, ffmpeg 5.0.1_3 -> 5.1.2_1, gd 2.3.3_2 -> 2.3.3_4, gdk-pixbuf 2.42.8 -> 2.42.10, gnutls 3.7.6 -> 3.7.8, gobject-introspection 1.72.0 -> 1.74.0, graphviz 5.0.0 -> 7.0.5, harfbuzz 4.4.1 -> 5.3.1, jpeg-xl 0.6.1 -> 0.7.0_1, leptonica 1.82.0 -> 1.82.0_1, libarchive 3.6.1 -> 3.6.2, libass 0.16.0 -> 0.17.0, libavif 0.10.1 -> 0.11.1, libbluray 1.3.1 -> 1.3.4, libidn2 2.3.3 -> 2.3.4, pango 1.50.8 -> 1.50.12, librsvg 2.54.4 -> 2.55.1, netpbm 10.86.33 -> 10.86.37, python@3.9 3.9.13_1 -> 3.9.16, webp 1.2.3 -> 1.2.4, scrcpy 1.24 -> 1.25
# ==> Fetching libarchive
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.6.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/blobs/sha256:dbb5277
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.2.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:51401f60176f1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for jpeg-xl: highway, imath and webp
# ==> Fetching highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.0.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/blobs/sha256:6f5347f6bb
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.6
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:9afc755be66e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.7.0_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/blobs/sha256:a9f204cf96
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for aom: highway, imath, webp and jpeg-xl
# ==> Fetching aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.5.0_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/blobs/sha256:e4fa96ccd7bfc3
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/blobs/sha256:335207a9dc
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for gnutls: ca-certificates, bdw-gc, readline, guile, libidn2, libtasn1, nettle, p11-kit, openssl@1.1, libnghttp2 and unbound
# ==> Fetching ca-certificates
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2022-
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/blobs/sha256:1b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching bdw-gc
# ==> Downloading https://ghcr.io/v2/homebrew/core/bdw-gc/manifests/8.2.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/bdw-gc/blobs/sha256:706ba9acedc
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching readline
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/manifests/8.2.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/blobs/sha256:19e6b02f5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching guile
# ==> Downloading https://ghcr.io/v2/homebrew/core/guile/manifests/3.0.8_3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/guile/blobs/sha256:d2e8968022b3
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libtasn1
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/manifests/4.19.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/blobs/sha256:2aa4f8396
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching nettle
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/manifests/3.8.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/blobs/sha256:19eca950c96
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching p11-kit
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.24.1_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/blobs/sha256:ce3a672349
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching openssl@1.1
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/manifests/1.1.1s
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/blobs/sha256:d91517
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.51.0-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:d94c9ee
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching unbound
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.17.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/blobs/sha256:6cf8bdba19
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching gnutls
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/manifests/3.7.8
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/blobs/sha256:6bd29803c83
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for gobject-introspection: ca-certificates, openssl@1.1, readline, sqlite and python@3.11
# ==> Fetching sqlite
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.40.0-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/blobs/sha256:eae786ad782
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching python@3.11
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.11/manifests/3.11.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.11/blobs/sha256:b66890
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching gobject-introspection
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/manifests
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/blobs/sha
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for harfbuzz: icu4c
# ==> Fetching icu4c
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/71.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:87617a04333c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/5.3.1-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:38b0743c9
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for libass: icu4c, harfbuzz and libunibreak
# ==> Fetching libunibreak
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/manifests/5.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/blobs/sha256:ad5718
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libass
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/manifests/0.17.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/blobs/sha256:eb7c43548a6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libbluray
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/manifests/1.3.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/blobs/sha256:675911bf
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for leptonica: webp
# ==> Fetching leptonica
# ==> Downloading https://ghcr.io/v2/homebrew/core/leptonica/manifests/1.82.0_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/leptonica/blobs/sha256:d38cfdaa
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for ffmpeg: highway, imath, webp, jpeg-xl, aom, ca-certificates, bdw-gc, readline, guile, libidn2, libtasn1, nettle, p11-kit, openssl@1.1, libnghttp2, unbound, gnutls, icu4c, harfbuzz, libunibreak, libass, libbluray, mbedtls, librist, opencore-amr, rav1e, flac, mpg123, libsndfile, rubberband, sdl2, srt, leptonica and libarchive
# ==> Fetching mbedtls
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/manifests/3.3.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/blobs/sha256:ea76327878
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching librist
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/manifests/0.2.7_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/blobs/sha256:fb0dda69a5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching opencore-amr
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/manifests/0.1.6
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/blobs/sha256:cc0a0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching rav1e
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/manifests/0.6.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/blobs/sha256:c26df3fe0341
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching flac
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/manifests/1.4.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/blobs/sha256:7afd024db3ea4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching mpg123
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpg123/manifests/1.31.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpg123/blobs/sha256:8a768946363
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libsndfile
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/manifests/1.1.0_1-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/blobs/sha256:39def19
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching rubberband
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/manifests/3.1.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/blobs/sha256:4ae7e36
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching sdl2
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/manifests/2.26.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/blobs/sha256:c9072ab2b0047
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching srt
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/manifests/1.5.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/blobs/sha256:9cb143f5b2a095
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching ffmpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/manifests/5.1.2_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/blobs/sha256:0c3cd448280
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for libavif: highway, imath, webp, jpeg-xl and aom
# ==> Fetching libavif
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/manifests/0.11.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/blobs/sha256:62c3120e7b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for gd: highway, imath, webp, jpeg-xl, aom and libavif
# ==> Fetching gd
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/manifests/2.3.3_4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/blobs/sha256:220d7e3cd2bef8d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching gdk-pixbuf
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/manifests/2.42.10
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/blobs/sha256:4494ae1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for netpbm: jasper
# ==> Fetching jasper
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/4.0.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/blobs/sha256:81f52cc0adf
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching netpbm
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/10.86.37
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/blobs/sha256:d9e210cc4ab
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for pango: icu4c and harfbuzz
# ==> Fetching pango
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.50.12
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/blobs/sha256:8c06a68283a0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for librsvg: gdk-pixbuf, icu4c, harfbuzz and pango
# ==> Fetching librsvg
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/manifests/2.55.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/blobs/sha256:a60462f069
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for graphviz: highway, imath, webp, jpeg-xl, aom, libavif, gd, jasper, netpbm, gdk-pixbuf, icu4c, harfbuzz, pango and librsvg
# ==> Fetching graphviz
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/manifests/7.0.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/blobs/sha256:3b182d1ea
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for python@3.9: ca-certificates, openssl@1.1, readline and sqlite
# ==> Fetching python@3.9
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/manifests/3.9.16
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/blobs/sha256:f048ad5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching dependencies for scrcpy: highway, imath, webp, jpeg-xl, aom, ca-certificates, bdw-gc, readline, guile, libidn2, libtasn1, nettle, p11-kit, openssl@1.1, libnghttp2, unbound, gnutls, icu4c, harfbuzz, libunibreak, libass, libbluray, mbedtls, librist, opencore-amr, rav1e, flac, mpg123, libsndfile, rubberband, sdl2, srt, leptonica, libarchive and ffmpeg
# ==> Fetching scrcpy
# ==> Downloading https://ghcr.io/v2/homebrew/core/scrcpy/manifests/1.25
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/scrcpy/blobs/sha256:9612404cadb
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Upgrading libarchive
#   3.6.1 -> 3.6.2
#
# ==> Pouring libarchive--3.6.2.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libarchive/3.6.2: 62 files, 3.6MB
# ==> Running `brew cleanup libarchive`...
# Removing: /usr/local/Cellar/libarchive/3.6.1... (62 files, 3.6MB)
# Removing: /Users/profq/Library/Caches/Homebrew/libarchive--3.6.1... (1.5MB)
# ==> Upgrading webp
#   1.2.3 -> 1.2.4
#
# ==> Pouring webp--1.2.4.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/webp/1.2.4: 41 files, 2.5MB
# ==> Running `brew cleanup webp`...
# Removing: /usr/local/Cellar/webp/1.2.3... (41 files, 2.5MB)
# Removing: /Users/profq/Library/Caches/Homebrew/webp--1.2.3... (888.8KB)
# ==> Upgrading jpeg-xl
#   0.6.1 -> 0.7.0_1
#
# ==> Installing dependencies for jpeg-xl: highway and imath
# ==> Installing jpeg-xl dependency: highway
# ==> Pouring highway--1.0.2.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/highway/1.0.2: 61 files, 3.5MB
# ==> Installing jpeg-xl dependency: imath
# ==> Pouring imath--3.1.6.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/imath/3.1.6: 49 files, 927KB
# ==> Installing jpeg-xl
# ==> Pouring jpeg-xl--0.7.0_1.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/jpeg-xl/0.7.0_1: 41 files, 16.2MB
# ==> Running `brew cleanup jpeg-xl`...
# Removing: /usr/local/Cellar/jpeg-xl/0.6.1... (61 files, 17.6MB)
# Removing: /Users/profq/Library/Caches/Homebrew/jpeg-xl--0.6.1... (6.4MB)
# ==> Upgrading aom
#   3.4.0 -> 3.5.0_1
#
# ==> Pouring aom--3.5.0_1.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/aom/3.5.0_1: 23 files, 13.7MB
# ==> Running `brew cleanup aom`...
# Removing: /usr/local/Cellar/aom/3.4.0... (23 files, 13.7MB)
# Removing: /Users/profq/Library/Caches/Homebrew/aom--3.4.0... (4.5MB)
# ==> Upgrading libidn2
#   2.3.3 -> 2.3.4
#
# ==> Pouring libidn2--2.3.4.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libidn2/2.3.4: 79 files, 1.2MB
# ==> Running `brew cleanup libidn2`...
# Removing: /usr/local/Cellar/libidn2/2.3.2... (77 files, 846.7KB)
# Removing: /usr/local/Cellar/libidn2/2.3.3... (78 files, 987.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libidn2--2.3.3... (317.6KB)
# ==> Upgrading gnutls
#   3.7.6 -> 3.7.8
#
# ==> Installing dependencies for gnutls: ca-certificates, bdw-gc, readline, guile, libtasn1, nettle, p11-kit, openssl@1.1, libnghttp2 and unbound
# ==> Installing gnutls dependency: ca-certificates
# ==> Pouring ca-certificates--2022-10-11.all.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# ...
# Removing: /Users/profq/Library/Caches/Homebrew/opus--1.3.1... (444.7KB)
# Removing: /usr/local/Cellar/p11-kit/0.24.1... (67 files, 3.5MB)
# Removing: /Users/profq/Library/Caches/Homebrew/p11-kit--0.24.1... (872.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/pcre--8.45... (1.8MB)
# Removing: /usr/local/Cellar/pixman/0.40.0... (11 files, 1.3MB)
# Removing: /Users/profq/Library/Caches/Homebrew/pixman--0.40.0... (510.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/pkg-config--0.29.2_3... (238.9KB)
# Removing: /usr/local/Cellar/rav1e/0.5.1... (13 files, 118.9MB)
# Removing: /Users/profq/Library/Caches/Homebrew/rav1e--0.5.1... (39.3MB)
# Removing: /usr/local/Cellar/readline/8.1.2... (48 files, 1.6MB)
# Removing: /Users/profq/Library/Caches/Homebrew/readline--8.1.2... (534.7KB)
# Removing: /usr/local/Cellar/rubberband/2.0.2... (12 files, 1.1MB)
# Removing: /usr/local/Cellar/rubberband/3.0.0... (13 files, 1.6MB)
# Removing: /Users/profq/Library/Caches/Homebrew/rubberband--3.0.0... (553.9KB)
# Removing: /usr/local/Cellar/sdl2/2.0.22... (92 files, 5.7MB)
# Removing: /Users/profq/Library/Caches/Homebrew/sdl2--2.0.22... (1.6MB)
# Removing: /Users/profq/Library/Caches/Homebrew/snappy--1.1.9... (43.6KB)
# Removing: /usr/local/Cellar/speex/1.2.0... (21 files, 713.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/speex--1.2.1... (538.9KB)
# Removing: /usr/local/Cellar/sqlite/3.39.1... (11 files, 4.4MB)
# Removing: /Users/profq/Library/Caches/Homebrew/sqlite--3.39.1... (2MB)
# Removing: /usr/local/Cellar/srt/1.5.0... (20 files, 4.1MB)
# Removing: /Users/profq/Library/Caches/Homebrew/srt--1.5.0... (1.6MB)
# Removing: /Users/profq/Library/Caches/Homebrew/tesseract--5.2.0... (11.8MB)
# Removing: /Users/profq/Library/Caches/Homebrew/theora--1.1.1... (698.8KB)
# Removing: /usr/local/Cellar/unbound/1.16.1... (58 files, 5.7MB)
# Removing: /Users/profq/Library/Caches/Homebrew/unbound--1.16.1... (2.8MB)
# Removing: /Users/profq/Library/Caches/Homebrew/x264--r3095... (2.3MB)
# Removing: /Users/profq/Library/Caches/Homebrew/x265--3.5... (5MB)
# Removing: /usr/local/Cellar/xorgproto/2022.1... (264 files, 3.9MB)
# Removing: /Users/profq/Library/Caches/Homebrew/xorgproto--2022.1... (695.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/xvid--1.3.7... (457KB)
# Removing: /usr/local/Cellar/xz/5.2.5_1... (95 files, 1.3MB)
# Removing: /Users/profq/Library/Caches/Homebrew/xz--5.2.5... (415.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/xz--5.2.5_1... (415.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/zeromq--4.3.4... (1.6MB)
# Removing: /Users/profq/Library/Caches/Homebrew/zimg--3.0.4... (691.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/zstd--1.5.2... (894.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libusb_bottle_manifest--1.0.26... (7.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/mbedtls_bottle_manifest--3.1.0... (6.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/cairo_bottle_manifest--1.16.0_5... (22KB)
# Removing: /Users/profq/Library/Caches/Homebrew/gts_bottle_manifest--0.7.6_2... (18.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/srt_bottle_manifest--1.5.0... (7.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/nettle_bottle_manifest--3.8... (6.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/gnutls_bottle_manifest--3.7.6... (15.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/lz4_bottle_manifest--1.9.3... (7.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/guile_bottle_manifest--3.0.8... (10.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/rav1e_bottle_manifest--0.5.1... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/brotli_bottle_manifest--1.0.9... (8.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/descriptions.json... (343.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/cmocka_bottle_manifest--1.1.5... (8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/graphite2_bottle_manifest--1.3.14... (7.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/cask_descriptions.json... (261.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libvidstab_bottle_manifest--1.1.0-1... (7.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/leptonica_bottle_manifest--1.82.0... (11.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libvpx_bottle_manifest--1.11.0... (7.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/scrcpy_bottle_manifest--1.24... (53.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/unbound_bottle_manifest--1.16.0... (10.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/gmp_bottle_manifest--6.2.1_1... (7.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/speex_bottle_manifest--1.2.0... (10.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/tesseract_bottle_manifest--5.1.0... (12.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/gdbm_bottle_manifest--1.23... (6.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/xz_bottle_manifest--5.2.5... (7.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/frei0r_bottle_manifest--1.8.0... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libx11_bottle_manifest--1.8.1... (12.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/fontconfig_bottle_manifest--2.14.0... (8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/m4_bottle_manifest--1.4.19... (7.0KB)
# Removing: /Users/profq/Library/Caches/Homebrew/speex_bottle_manifest--1.2.1... (6.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/unbound_bottle_manifest--1.16.1... (10.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/gobject-introspection_bottle_manifest--1.72.0... (21.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libxau_bottle_manifest--1.0.9... (8.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/librsvg_bottle_manifest--2.54.4... (24.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/bdw-gc_bottle_manifest--8.0.6... (7.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/cjson_bottle_manifest--1.7.15... (8.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libogg_bottle_manifest--1.3.5... (7.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/srt_bottle_manifest--1.4.4... (8.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libxext_bottle_manifest--1.3.4... (11.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libass_bottle_manifest--0.16.0... (21.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libnghttp2_bottle_manifest--1.47.0... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/pcre_bottle_manifest--8.45... (8.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/openssl@1.1_bottle_manifest--1.1.1q... (7.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/ffmpeg_bottle_manifest--5.0.1_1... (55.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/opencore-amr_bottle_manifest--0.1.5... (10.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/rubberband_bottle_manifest--2.0.2... (14.0KB)
# Removing: /Users/profq/Library/Caches/Homebrew/jpeg-xl_bottle_manifest--0.6.1... (11.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/lame_bottle_manifest--3.100... (8.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/graphviz_bottle_manifest--3.0.0... (34.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/mbedtls_bottle_manifest--3.2.1... (6.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/ca-certificates_bottle_manifest--2022-04-26... (1.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libsamplerate_bottle_manifest--0.1.9_1-1... (10.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/tesseract_bottle_manifest--5.2.0... (12.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/python@3.9_bottle_manifest--3.9.13_1... (18.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/zstd_bottle_manifest--1.5.2-2... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/p11-kit_bottle_manifest--0.24.1... (8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/x265_bottle_manifest--3.5-1... (7.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/glib_bottle_manifest--2.72.2_1... (9.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libvpx_bottle_manifest--1.12.0... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/unbound_bottle_manifest--1.15.0... (10.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/graphviz_bottle_manifest--5.0.0... (34.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libb2_bottle_manifest--0.98.1... (8.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/librist_bottle_manifest--0.2.7... (7.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/nettle_bottle_manifest--3.7.3... (7.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libtasn1_bottle_manifest--4.18.0... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libxrender_bottle_manifest--0.9.10... (11.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libvmaf_bottle_manifest--2.3.1... (6.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/snappy_bottle_manifest--1.1.9... (7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/zimg_bottle_manifest--3.0.4... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/freetype_bottle_manifest--2.12.1... (7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/sqlite_bottle_manifest--3.39.1... (6.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/xvid_bottle_manifest--1.3.7... (7.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libidn2_bottle_manifest--2.3.2... (8.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/harfbuzz_bottle_manifest--4.4.1... (21.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/pixman_bottle_manifest--0.40.0... (7.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/giflib_bottle_manifest--5.2.1... (7.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/gdk-pixbuf_bottle_manifest--2.42.8... (14.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/ca-certificates_bottle_manifest--2022-07-19_1... (1.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libnghttp2_bottle_manifest--1.48.0... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libx11_bottle_manifest--1.8... (12.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libidn2_bottle_manifest--2.3.3... (7.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libpng_bottle_manifest--1.6.37... (8.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libxdmcp_bottle_manifest--1.1.3... (8.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libavif_bottle_manifest--0.10.1... (10.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/openjpeg_bottle_manifest--2.5.0... (8.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/xz_bottle_manifest--5.2.5_1... (6.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libsoxr_bottle_manifest--0.1.3-1... (8.0KB)
# Removing: /Users/profq/Library/Caches/Homebrew/jasper_bottle_manifest--3.0.4... (11KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libbluray_bottle_manifest--1.3.1... (8.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/openexr_bottle_manifest--3.1.5... (6.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libvorbis_bottle_manifest--1.3.7... (8.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/gd_bottle_manifest--2.3.3_2... (12.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/lzo_bottle_manifest--2.10... (9.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/aom_bottle_manifest--3.3.0... (10KB)
# Removing: /Users/profq/Library/Caches/Homebrew/jasper_bottle_manifest--3.0.6_1... (6.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/imath_bottle_manifest--3.1.5... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/jpeg_bottle_manifest--9e... (6.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/flac_bottle_manifest--1.3.4... (6.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/sqlite_bottle_manifest--3.38.5... (6.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/mpdecimal_bottle_manifest--2.5.1... (6.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/x264_bottle_manifest--r3095... (6.9KB)
# Removing: /Users/profq/Library/Caches/Homebrew/netpbm_bottle_manifest--10.86.33... (12.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/ffmpeg_bottle_manifest--5.0.1_2... (55.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/harfbuzz_bottle_manifest--4.3.0... (21.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libsodium_bottle_manifest--1.0.18_1... (7.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/xorgproto_bottle_manifest--2022.1... (11.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/openssl@1.1_bottle_manifest--1.1.1o... (7.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libxcb_bottle_manifest--1.15... (13.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/dav1d_bottle_manifest--1.0.0... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/glib_bottle_manifest--2.72.2... (15.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/gettext_bottle_manifest--0.21... (10.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libsndfile_bottle_manifest--1.1.0-1... (8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/ffmpeg_bottle_manifest--5.0.1_3... (55.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/rubberband_bottle_manifest--3.0.0... (10.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/x264_bottle_manifest--r3060... (7.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/readline_bottle_manifest--8.1.2... (6.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libevent_bottle_manifest--2.1.12... (9.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libpthread-stubs_bottle_manifest--0.4... (8.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/zeromq_bottle_manifest--4.3.4... (7.6KB)
# Removing: /Users/profq/Library/Caches/Homebrew/pango_bottle_manifest--1.50.6... (22.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/webp_bottle_manifest--1.2.2... (8.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/aom_bottle_manifest--3.4.0... (10KB)
# Removing: /Users/profq/Library/Caches/Homebrew/little-cms2_bottle_manifest--2.13.1... (7.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libffi_bottle_manifest--3.4.2... (7.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libunistring_bottle_manifest--1.0... (6.2KB)
# Removing: /Users/profq/Library/Caches/Homebrew/icu4c_bottle_manifest--70.1... (7.1KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libtool_bottle_manifest--2.4.7... (7.0KB)
# Removing: /Users/profq/Library/Caches/Homebrew/pango_bottle_manifest--1.50.8... (22.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/pkg-config_bottle_manifest--0.29.2_3... (7.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libarchive_bottle_manifest--3.6.1... (8.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/librist_bottle_manifest--0.2.7_1... (7.7KB)
# Removing: /Users/profq/Library/Caches/Homebrew/theora_bottle_manifest--1.1.1-4... (8.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/opus_bottle_manifest--1.3.1-1... (7.5KB)
# Removing: /Users/profq/Library/Caches/Homebrew/libtiff_bottle_manifest--4.4.0... (7.0KB)
# Removing: /Users/profq/Library/Caches/Homebrew/fribidi_bottle_manifest--1.0.12... (6.3KB)
# Removing: /Users/profq/Library/Caches/Homebrew/sdl2_bottle_manifest--2.0.22... (10.4KB)
# Removing: /Users/profq/Library/Caches/Homebrew/webp_bottle_manifest--1.2.3... (8.8KB)
# Removing: /Users/profq/Library/Caches/Homebrew/Cask/android-platform-tools--33.0.2.zip... (12.4MB)
# Removing: /Users/profq/Library/Logs/Homebrew/rubberband... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/ffmpeg... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/libidn2... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/speex... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/mbedtls... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/srt... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/tesseract... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/libnghttp2... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/libvpx... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/librist... (64B)
# Removing: /Users/profq/Library/Logs/Homebrew/unbound... (64B)
# Pruned 0 symbolic links and 4 directories from /usr/local
# ==> Caveats
# ==> scrcpy
# At runtime, adb must be accessible from your PATH.
#
# You can install adb from Homebrew Cask:
#   brew install --cask android-platform-tools
#
# zsh completions have been installed to:
#   /usr/local/share/zsh/site-functions
